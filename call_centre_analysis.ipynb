# %% [markdown]
# ## import pandas

# %% [markdown]
# import pandas as pd

# %% [markdown]
# ### read data

# %%
df = pd.read_csv('mock_call_centre_data.csv')

# %%
df.head()
# Out:
#                                            StartDate  \
# 0                                         Start Date
# 1  {"ImportId":"startDate","timeZone":"America/Ne...
# 2                                   2017-02-03 20:08
# 3                                   2017-02-06 15:13
# 4                                    2017-02-09 9:49
#
#                                              EndDate                 Status  \
# 0                                           End Date          Response Type
# 1  {"ImportId":"endDate","timeZone":"America/New_...  {"ImportId":"status"}
# 2                                   2017-02-03 20:11             IP Address
# 3                                   2017-02-06 15:16             IP Address
# 4                                    2017-02-09 9:53             IP Address
#
#                   IPAddress                 Progress    Duration (in seconds)  \
# 0                IP Address                 Progress    Duration (in seconds)
# ...

# %%
# !ls
# Out:
#  mock_call_centre_data.csv   README.md	  requirements.txt
# '#README.md#'		     README.md~   Untitled.ipynb
